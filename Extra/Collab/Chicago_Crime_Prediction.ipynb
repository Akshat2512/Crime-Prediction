# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Dataset Resampling

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/Othercomputers/My laptop/php/Crime_Database/Chicago_Crimes_-_2001_to_Present_20240512.csv",on_bad_lines='skip')
# df = pd.read_csv("https://data.cityofchicago.org/resource/ijzp-q8t2.csv?$limit=90000000&$where=date%20between%20'2001-01-01T00:00:00'%20and%20'2024-12-31T23:00:00'&$order=date%20ASC")
df
# Out:
#                id                     date                   ofns_desc  \
# 0         4421965  2001-01-01T00:00:00.000                       THEFT
# 1        13246664  2001-01-01T00:00:00.000     CRIMINAL SEXUAL ASSAULT
# 2        13395042  2001-01-01T00:00:00.000  OFFENSE INVOLVING CHILDREN
# 3        12674158  2001-01-01T00:00:00.000     CRIMINAL SEXUAL ASSAULT
# 4         4349650  2001-01-01T00:00:00.000                       THEFT
# ...           ...                      ...                         ...
# 8063373  13458145  2024-05-12T00:00:00.000                     BATTERY
# 8063374  13458081  2024-05-12T00:00:00.000                 SEX OFFENSE
# 8063375  13457440  2024-05-12T00:00:00.000                     BATTERY
# 8063376  13459989  2024-05-12T00:00:00.000         MOTOR VEHICLE THEFT
# 8063377  13458356  2024-05-12T00:00:00.000         MOTOR VEHICLE THEFT
#
#           prem_type_desc                    boro_nm  district  arrest  \
# 0              APARTMENT        056XX S WOLCOTT AVE       7.0   False
# 1              RESIDENCE   045XX N CENTRAL PARK AVE      17.0   False
# 2              APARTMENT      032XX W EVERGREEN AVE      14.0   False
# 3              RESIDENCE            029XX E 77TH ST       4.0   False
# 4              RESIDENCE           004XX W 126TH PL       5.0   False
# ...                  ...                        ...       ...     ...
# 8063373        RESIDENCE        096XX S BRENNAN AVE       4.0    True
# 8063374  APPLIANCE STORE  085XX S COTTAGE GROVE AVE       6.0   False
# 8063375        APARTMENT            038XX W 19TH ST      10.0   False
# 8063376           STREET          093XX S BISHOP ST      22.0   False
# 8063377      GAS STATION          018XX W DEVON AVE      24.0   False
#
#          domestic  longitude   latitude            crime_type
# 0           False -87.671629  41.790486          Theft Crimes
# 1           False        NaN        NaN  Assault and Violence
# 2            True        NaN        NaN          Other Crimes
# 3            True        NaN        NaN  Assault and Violence
# 4           False -87.633765  41.664388          Theft Crimes
# ...           ...        ...        ...                   ...
# 8063373      True -87.567870  41.720021  Assault and Violence
# 8063374     False -87.604897  41.739321       Sexual Offenses
# 8063375      True -87.721410  41.855030  Assault and Violence
# 8063376     False -87.659105  41.724434          Theft Crimes
# 8063377     False -87.676102  41.997973          Theft Crimes
#
# [8063378 rows x 11 columns]

# %%
df = df.drop(['id'], axis=1)

# %%
df = df.drop
# Out:
#                             date                   ofns_desc   prem_type_desc  \
# 0        2001-01-01T00:00:00.000                       THEFT        APARTMENT
# 1        2001-01-01T00:00:00.000     CRIMINAL SEXUAL ASSAULT        RESIDENCE
# 2        2001-01-01T00:00:00.000  OFFENSE INVOLVING CHILDREN        APARTMENT
# 3        2001-01-01T00:00:00.000     CRIMINAL SEXUAL ASSAULT        RESIDENCE
# 4        2001-01-01T00:00:00.000                       THEFT        RESIDENCE
# ...                          ...                         ...              ...
# 8063373  2024-05-12T00:00:00.000                     BATTERY        RESIDENCE
# 8063374  2024-05-12T00:00:00.000                 SEX OFFENSE  APPLIANCE STORE
# 8063375  2024-05-12T00:00:00.000                     BATTERY        APARTMENT
# 8063376  2024-05-12T00:00:00.000         MOTOR VEHICLE THEFT           STREET
# 8063377  2024-05-12T00:00:00.000         MOTOR VEHICLE THEFT      GAS STATION
#
#                            boro_nm  district  arrest  domestic  longitude  \
# 0              056XX S WOLCOTT AVE       7.0   False     False -87.671629
# 1         045XX N CENTRAL PARK AVE      17.0   False     False        NaN
# 2            032XX W EVERGREEN AVE      14.0   False      True        NaN
# 3                  029XX E 77TH ST       4.0   False      True        NaN
# 4                 004XX W 126TH PL       5.0   False     False -87.633765
# ...                            ...       ...     ...       ...        ...
# 8063373        096XX S BRENNAN AVE       4.0    True      True -87.567870
# 8063374  085XX S COTTAGE GROVE AVE       6.0   False     False -87.604897
# 8063375            038XX W 19TH ST      10.0   False      True -87.721410
# 8063376          093XX S BISHOP ST      22.0   False     False -87.659105
# 8063377          018XX W DEVON AVE      24.0   False     False -87.676102
#
#           latitude            crime_type
# 0        41.790486          Theft Crimes
# 1              NaN  Assault and Violence
# 2              NaN          Other Crimes
# 3              NaN  Assault and Violence
# 4        41.664388          Theft Crimes
# ...            ...                   ...
# 8063373  41.720021  Assault and Violence
# 8063374  41.739321       Sexual Offenses
# 8063375  41.855030  Assault and Violence
# 8063376  41.724434          Theft Crimes
# 8063377  41.997973          Theft Crimes
#
# [8063378 rows x 10 columns]

# %%
# df_x = df.groupby('Primary Type')

# %%
# df_x = df_x.get_group('ROBBERY')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8063378 entries, 0 to 8063377
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   ofns_desc       object
#  2   prem_type_desc  object
#  3   boro_nm         object
#  4   district        float64
#  5   arrest          bool
#  6   domestic        bool
#  7   longitude       float64
#  8   latitude        float64
#  9   crime_type      object
# dtypes: bool(2), float64(3), object(5)
# memory usage: 507.5+ MB

# %%
# df_c = pd.DataFrame([])

# %%
# df_c[['id', 'date', 'ofns_desc', 'prem_type_desc', 'boro_nm', 'district', 'arrest', 'domestic', 'longitude', 'latitude']] = df[['id', 'date', 'primary_type', 'location_description', 'block', 'district', 'arrest', 'domestic', 'longitude', 'latitude']]

# %%
# df_c = df_c.drop(['ID', 'Date', 'Primary Type', 'Location Description', 'Block', 'District', 'Arrest', 'Domestic', 'Longitude', 'Latitude'], axis=1)

# %%
# df_c

# %%
# df_c.to_csv("/content/drive/Othercomputers/My laptop/php/Crime_Database/Chicago_Crimes_-_2001_to_Present_20240512.csv", index = False)

# %%
df.isnull().sum()
# Out:
# id                    0
# date                  0
# ofns_desc             0
# prem_type_desc    13018
# boro_nm               0
# district             47
# arrest                0
# domestic              0
# longitude         88750
# latitude          88750
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# id                      0
# date                    0
# primary_type            0
# location_description    0
# block                   0
# district                0
# arrest                  0
# domestic                0
# dtype: int64

# %%
df = df.set_index('date')

# %%
df.index = pd.to_datetime(df.index)

# %%
df.tail(20)
# Out:
#                            id                ofns_desc  \
# date
# 2024-05-11 23:45:00  13457403                    THEFT
# 2024-05-11 23:50:00  13457419        WEAPONS VIOLATION
# 2024-05-11 23:54:00  13457423            OTHER OFFENSE
# 2024-05-11 23:54:00  13457416          CRIMINAL DAMAGE
# 2024-05-12 00:00:00  13457867            OTHER OFFENSE
# 2024-05-12 00:00:00  13457788                    THEFT
# 2024-05-12 00:00:00  13459270          CRIMINAL DAMAGE
# 2024-05-12 00:00:00  13457551                  ROBBERY
# 2024-05-12 00:00:00  13459409                  BATTERY
# 2024-05-12 00:00:00  13458289            OTHER OFFENSE
# 2024-05-12 00:00:00  13460373                    THEFT
# 2024-05-12 00:00:00  13460036                  BATTERY
# 2024-05-12 00:00:00  13462511  CRIMINAL SEXUAL ASSAULT
# 2024-05-12 00:00:00  13458371                  BATTERY
# 2024-05-12 00:00:00  13459578          CRIMINAL DAMAGE
# 2024-05-12 00:00:00  13458145                  BATTERY
# 2024-05-12 00:00:00  13458081              SEX OFFENSE
# 2024-05-12 00:00:00  13457440                  BATTERY
# 2024-05-12 00:00:00  13459989      MOTOR VEHICLE THEFT
# 2024-05-12 00:00:00  13458356      MOTOR VEHICLE THEFT
#
#                                              prem_type_desc  \
# date
# 2024-05-11 23:45:00                             GAS STATION
# 2024-05-11 23:50:00                                   ALLEY
# 2024-05-11 23:54:00                               RESIDENCE
# 2024-05-11 23:54:00                                  STREET
# 2024-05-12 00:00:00                                   ALLEY
# 2024-05-12 00:00:00                                  STREET
# 2024-05-12 00:00:00                                  STREET
# 2024-05-12 00:00:00                  VEHICLE NON-COMMERCIAL
# 2024-05-12 00:00:00                               APARTMENT
# 2024-05-12 00:00:00                               RESIDENCE
# 2024-05-12 00:00:00  PARKING LOT / GARAGE (NON RESIDENTIAL)
# 2024-05-12 00:00:00                               RESIDENCE
# 2024-05-12 00:00:00                               APARTMENT
# 2024-05-12 00:00:00                               APARTMENT
# 2024-05-12 00:00:00                                  STREET
# 2024-05-12 00:00:00                               RESIDENCE
# 2024-05-12 00:00:00                         APPLIANCE STORE
# 2024-05-12 00:00:00                               APARTMENT
# 2024-05-12 00:00:00                                  STREET
# 2024-05-12 00:00:00                             GAS STATION
#
#                                        boro_nm  district  arrest  domestic  \
# date
# 2024-05-11 23:45:00          015XX W GRAND AVE      12.0   False     False
# 2024-05-11 23:50:00        047XX S SHIELDS AVE       9.0   False     False
# 2024-05-11 23:54:00            031XX W 77TH ST       8.0   False      True
# 2024-05-11 23:54:00        062XX S KILDARE AVE       8.0   False     False
# 2024-05-12 00:00:00          018XX S PEORIA ST      12.0    True      True
# 2024-05-12 00:00:00           026XX W 101ST PL      22.0   False     False
# 2024-05-12 00:00:00       050XX N ST LOUIS AVE      17.0   False     False
# 2024-05-12 00:00:00        079XX S SAGINAW AVE       4.0   False     False
# 2024-05-12 00:00:00           0000X W 108TH ST       5.0   False      True
# 2024-05-12 00:00:00         034XX N KENTON AVE      17.0   False      True
# 2024-05-12 00:00:00        001XX N FRANKLIN ST       1.0   False     False
# 2024-05-12 00:00:00           001XX W 117TH ST       5.0   False      True
# 2024-05-12 00:00:00        068XX S EMERALD AVE       7.0   False     False
# 2024-05-12 00:00:00            010XX E 41ST PL       2.0   False      True
# 2024-05-12 00:00:00          046XX N DAMEN AVE      19.0   False     False
# 2024-05-12 00:00:00        096XX S BRENNAN AVE       4.0    True      True
# 2024-05-12 00:00:00  085XX S COTTAGE GROVE AVE       6.0   False     False
# 2024-05-12 00:00:00            038XX W 19TH ST      10.0   False      True
# 2024-05-12 00:00:00          093XX S BISHOP ST      22.0   False     False
# 2024-05-12 00:00:00          018XX W DEVON AVE      24.0   False     False
#
#                      longitude   latitude
# date
# 2024-05-11 23:45:00 -87.666203  41.890993
# 2024-05-11 23:50:00 -87.634556  41.808049
# 2024-05-11 23:54:00 -87.700676  41.753478
# 2024-05-11 23:54:00 -87.730096  41.779026
# 2024-05-12 00:00:00 -87.648283  41.857765
# 2024-05-12 00:00:00 -87.687667  41.709060
# 2024-05-12 00:00:00 -87.715947  41.973318
# 2024-05-12 00:00:00 -87.560165  41.751359
# 2024-05-12 00:00:00 -87.623942  41.698042
# 2024-05-12 00:00:00 -87.742038  41.943475
# 2024-05-12 00:00:00 -87.635403  41.885368
# 2024-05-12 00:00:00 -87.625840  41.681629
# 2024-05-12 00:00:00 -87.643196  41.770225
# 2024-05-12 00:00:00 -87.600302  41.819768
# 2024-05-12 00:00:00 -87.679097  41.965570
# 2024-05-12 00:00:00 -87.567870  41.720021
# 2024-05-12 00:00:00 -87.604897  41.739321
# 2024-05-12 00:00:00 -87.721410  41.855030
# 2024-05-12 00:00:00 -87.659105  41.724434
# 2024-05-12 00:00:00 -87.676102  41.997973

# %%
typ = 'h'
df_year = df.resample(typ).size().to_frame('Crime Count')
d_type = 'datetime64['+typ+']'
df_year
# Out:
#                      Crime Count
# date
# 2001-01-01 00:00:00          420
# 2001-01-01 01:00:00           91
# 2001-01-01 02:00:00           78
# 2001-01-01 03:00:00           71
# 2001-01-01 04:00:00           53
# ...                          ...
# 2024-05-11 20:00:00           31
# 2024-05-11 21:00:00           30
# 2024-05-11 22:00:00           32
# 2024-05-11 23:00:00           30
# 2024-05-12 00:00:00           16
#
# [204769 rows x 1 columns]

# %%
plt.figure(figsize=(9,4))
plt.plot(df_year.index, df_year['Crime Count'])
plt.title("Chicago Crime Count Per Hour")
plt.xlabel("Time")
plt.ylabel("Number of Crimes")
# Out:
# Text(0, 0.5, 'Number of Crimes')

# %%
df_year = df_year.reset_index()
df_year

# %%
df_year.to_csv('/content/drive/Othercomputers/My laptop/php/Crime_Database/Chicago_2001_2023.csv', index = False)

# %% [markdown]
# #Data Preparation

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_year=pd.read_csv('/content/drive/Othercomputers/My laptop/php/Crime_Database/Chicago_2001_2023.csv')

# %%
df_year
# Out:
#                        date  Crime Count
# 0       2001-01-01 00:00:00          420
# 1       2001-01-01 01:00:00           91
# 2       2001-01-01 02:00:00           78
# 3       2001-01-01 03:00:00           71
# 4       2001-01-01 04:00:00           53
# ...                     ...          ...
# 204764  2024-05-11 20:00:00           31
# 204765  2024-05-11 21:00:00           30
# 204766  2024-05-11 22:00:00           32
# 204767  2024-05-11 23:00:00           30
# 204768  2024-05-12 00:00:00           16
#
# [204769 rows x 2 columns]

# %%
df_year = df_year.set_index('date')

# %%
df_year.index =  pd.to_datetime(df_year.index,format = '%Y-%m-%d %H:%M:%S')
df_year = df_year[(df_year.index >='2001') & (df_year.index <='2025') ]

# %%
start = '2023-10-20'
end = '2023-10-30'

# %%
df_year
# Out:
#                      Crime Count
# date
# 2001-01-01 00:00:00          420
# 2001-01-01 01:00:00           91
# 2001-01-01 02:00:00           78
# 2001-01-01 03:00:00           71
# 2001-01-01 04:00:00           53
# ...                          ...
# 2024-05-11 20:00:00           31
# 2024-05-11 21:00:00           30
# 2024-05-11 22:00:00           32
# 2024-05-11 23:00:00           30
# 2024-05-12 00:00:00           16
#
# [204769 rows x 1 columns]

# %% [markdown]
# ###Features Creation

# %%
from datetime import date, timedelta
import pandas as pd
import holidays

# Create a list of dates from 1 Jan 2023 to 1 Jan 2024
start_date = df_year.head(1).index.date[0]
end_date = df_year.tail(1).index.date[0]

delta = timedelta(days=1)
dates = []
while start_date <= end_date:
    dates.append(start_date)
    start_date += delta

# Create a DataFrame
df_h = pd.DataFrame(dates, columns=['Date'])

# Get US holidays
us_holidays = holidays.US(state='IL')

# Create a column for holidays
df_h['Holiday'] = df_h['Date'].apply(lambda x: us_holidays.get(x))

df_h.head()
# Out:
#          Date         Holiday
# 0  2001-01-01  New Year's Day
# 1  2001-01-02            None
# 2  2001-01-03            None
# 3  2001-01-04            None
# 4  2001-01-05            None

# %%
df_h['Date'] = pd.to_datetime(df_h['Date'], format = '%Y-%m-%d')

df_h.set_index('Date',inplace=True)

df_h[df_h['Holiday'].isnull()] = 0;
df_h[df_h['Holiday'] != 0] = 1;

df_h = df_h.resample('H').ffill()
df_h
# Out:
#                     Holiday
# Date
# 2001-01-01 00:00:00       1
# 2001-01-01 01:00:00       1
# 2001-01-01 02:00:00       1
# 2001-01-01 03:00:00       1
# 2001-01-01 04:00:00       1
# ...                     ...
# 2024-05-11 20:00:00       0
# 2024-05-11 21:00:00       0
# 2024-05-11 22:00:00       0
# 2024-05-11 23:00:00       0
# 2024-05-12 00:00:00       0
#
# [204769 rows x 1 columns]

# %%
df_h=df_h['Holiday'].astype('int32')

# %%
df_h = df_h.to_frame('Holiday')

# %%
# weekday_mapping = {
#     'Monday': 1,
#     'Tuesday': 2,
#     'Wednesday': 3,
#     'Thursday': 4,
#     'Friday': 5,
#     'Saturday': 6,
#     'Sunday': 7
# }

def create_features(df_year):

    df = df_year.copy()

    df['date'] = df.index
    df['hour'] = df['date'].dt.hour
    df['dayofweek'] = df['date'].dt.dayofweek
    # df['weekday'] = df['date'].dt.day_name()
    # df['weekday'] = df['weekday'].map(weekday_mapping)
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['weekofyear'] = df['date'].dt.isocalendar().week
    df['date_offset'] = (df.date.dt.month*100 + df.date.dt.day - 320)%1300

    df['season'] = pd.cut(df['date_offset'], [0, 300, 602, 900, 1300],
                          labels=[0, 1, 2, 3] # 0 = 'Spring', 1 = 'Summer', 2 = 'Fall', 3 = 'Winter'
                          )
    df['holiday'] = df_h['Holiday']
    df.loc[df['dayofweek'].isin([5, 6]), 'holiday'] = 1

    df=df.dropna()
    print(df)
    return df

FEATURES = ['hour','dayofweek','quarter','month','year',
          'dayofyear','dayofmonth','weekofyear',
           'season', 'holiday']
TARGET = 'Crime Count'

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import StandardScaler


# def error(y_true, y_pred):
#   y_pred = np.array(y_pred)
#   y_true = np.array(y_true)
#   error = np.abs(y_true - y_pred) / y_true
#   return np.mean(error) * 100

# def mean_absolute_percentage_error(y_true, y_pred):
#     """Calculates MAPE given y_true and y_pred"""
#     y_true, y_pred = np.array(y_true), np.array(y_pred)
#     return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
state = 'Chicago'

df_n = create_features(df_year)
# df_n
# Out:
#                      Crime Count                date  hour  dayofweek  \
# date
# 2001-01-01 00:00:00          420 2001-01-01 00:00:00     0          0
# 2001-01-01 01:00:00           91 2001-01-01 01:00:00     1          0
# 2001-01-01 02:00:00           78 2001-01-01 02:00:00     2          0
# 2001-01-01 03:00:00           71 2001-01-01 03:00:00     3          0
# 2001-01-01 04:00:00           53 2001-01-01 04:00:00     4          0
# ...                          ...                 ...   ...        ...
# 2024-05-11 20:00:00           31 2024-05-11 20:00:00    20          5
# 2024-05-11 21:00:00           30 2024-05-11 21:00:00    21          5
# 2024-05-11 22:00:00           32 2024-05-11 22:00:00    22          5
# 2024-05-11 23:00:00           30 2024-05-11 23:00:00    23          5
# 2024-05-12 00:00:00           16 2024-05-12 00:00:00     0          6
#
#                      quarter  month  year  dayofyear  dayofmonth  weekofyear  \
# date
# 2001-01-01 00:00:00        1      1  2001          1           1           1
# 2001-01-01 01:00:00        1      1  2001          1           1           1
# 2001-01-01 02:00:00        1      1  2001          1           1           1
# 2001-01-01 03:00:00        1      1  2001          1           1           1
# 2001-01-01 04:00:00        1      1  2001          1           1           1
# ...                      ...    ...   ...        ...         ...         ...
# 2024-05-11 20:00:00        2      5  2024        132          11          19
# 2024-05-11 21:00:00        2      5  2024        132          11          19
# 2024-05-11 22:00:00        2      5  2024        132          11          19
# 2024-05-11 23:00:00        2      5  2024        132          11          19
# 2024-05-12 00:00:00        2      5  2024        133          12          19
#
#                      date_offset season  holiday
# date
# 2001-01-01 00:00:00         1081      3        1
# 2001-01-01 01:00:00         1081      3        1
# 2001-01-01 02:00:00         1081      3        1
# 2001-01-01 03:00:00         1081      3        1
# 2001-01-01 04:00:00         1081      3        1
# ...                          ...    ...      ...
# 2024-05-11 20:00:00          191      0        1
# 2024-05-11 21:00:00          191      0        1
# 2024-05-11 22:00:00          191      0        1
# 2024-05-11 23:00:00          191      0        1
# 2024-05-12 00:00:00          192      0        1
#
# [204193 rows x 13 columns]

# %% [markdown]
# ###Train/Test Split

# %%
X = df_n[FEATURES]# Input variable
y = df_n[TARGET] # Output variable
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=None, shuffle = False)

# %%
X_train
# Out:
#                      hour  dayofweek  quarter  month  year  dayofyear  \
# date
# 2001-01-01 00:00:00     0          0        1      1  2001          1
# 2001-01-01 01:00:00     1          0        1      1  2001          1
# 2001-01-01 02:00:00     2          0        1      1  2001          1
# 2001-01-01 03:00:00     3          0        1      1  2001          1
# 2001-01-01 04:00:00     4          0        1      1  2001          1
# ...                   ...        ...      ...    ...   ...        ...
# 2017-05-09 10:00:00    10          1        2      5  2017        129
# 2017-05-09 11:00:00    11          1        2      5  2017        129
# 2017-05-09 12:00:00    12          1        2      5  2017        129
# 2017-05-09 13:00:00    13          1        2      5  2017        129
# 2017-05-09 14:00:00    14          1        2      5  2017        129
#
#                      dayofmonth  weekofyear season  holiday
# date
# 2001-01-01 00:00:00           1           1      3        1
# 2001-01-01 01:00:00           1           1      3        1
# 2001-01-01 02:00:00           1           1      3        1
# 2001-01-01 03:00:00           1           1      3        1
# 2001-01-01 04:00:00           1           1      3        1
# ...                         ...         ...    ...      ...
# 2017-05-09 10:00:00           9          19      0        0
# 2017-05-09 11:00:00           9          19      0        0
# 2017-05-09 12:00:00           9          19      0        0
# 2017-05-09 13:00:00           9          19      0        0
# 2017-05-09 14:00:00           9          19      0        0
#
# [142935 rows x 10 columns]

# %%
X_test
# Out:
#                      hour  dayofweek  quarter  month  year  dayofyear  \
# date
# 2017-05-09 15:00:00    15          1        2      5  2017        129
# 2017-05-09 16:00:00    16          1        2      5  2017        129
# 2017-05-09 17:00:00    17          1        2      5  2017        129
# 2017-05-09 18:00:00    18          1        2      5  2017        129
# 2017-05-09 19:00:00    19          1        2      5  2017        129
# ...                   ...        ...      ...    ...   ...        ...
# 2024-05-11 20:00:00    20          5        2      5  2024        132
# 2024-05-11 21:00:00    21          5        2      5  2024        132
# 2024-05-11 22:00:00    22          5        2      5  2024        132
# 2024-05-11 23:00:00    23          5        2      5  2024        132
# 2024-05-12 00:00:00     0          6        2      5  2024        133
#
#                      dayofmonth  weekofyear season  holiday
# date
# 2017-05-09 15:00:00           9          19      0        0
# 2017-05-09 16:00:00           9          19      0        0
# 2017-05-09 17:00:00           9          19      0        0
# 2017-05-09 18:00:00           9          19      0        0
# 2017-05-09 19:00:00           9          19      0        0
# ...                         ...         ...    ...      ...
# 2024-05-11 20:00:00          11          19      0        1
# 2024-05-11 21:00:00          11          19      0        1
# 2024-05-11 22:00:00          11          19      0        1
# 2024-05-11 23:00:00          11          19      0        1
# 2024-05-12 00:00:00          12          19      0        1
#
# [61258 rows x 10 columns]

# %%
y_test
# Out:
# date
# 2017-05-09 15:00:00    43
# 2017-05-09 16:00:00    39
# 2017-05-09 17:00:00    47
# 2017-05-09 18:00:00    45
# 2017-05-09 19:00:00    47
#                        ..
# 2024-05-11 20:00:00    31
# 2024-05-11 21:00:00    30
# 2024-05-11 22:00:00    32
# 2024-05-11 23:00:00    30
# 2024-05-12 00:00:00    16
# Name: Crime Count, Length: 61258, dtype: int64

# %%
df_n
# Out:
#                      Crime Count                date  hour  dayofweek  \
# date
# 2001-01-01 00:00:00          420 2001-01-01 00:00:00     0          0
# 2001-01-01 01:00:00           91 2001-01-01 01:00:00     1          0
# 2001-01-01 02:00:00           78 2001-01-01 02:00:00     2          0
# 2001-01-01 03:00:00           71 2001-01-01 03:00:00     3          0
# 2001-01-01 04:00:00           53 2001-01-01 04:00:00     4          0
# ...                          ...                 ...   ...        ...
# 2024-05-11 20:00:00           31 2024-05-11 20:00:00    20          5
# 2024-05-11 21:00:00           30 2024-05-11 21:00:00    21          5
# 2024-05-11 22:00:00           32 2024-05-11 22:00:00    22          5
# 2024-05-11 23:00:00           30 2024-05-11 23:00:00    23          5
# 2024-05-12 00:00:00           16 2024-05-12 00:00:00     0          6
#
#                      quarter  month  year  dayofyear  dayofmonth  weekofyear  \
# date
# 2001-01-01 00:00:00        1      1  2001          1           1           1
# 2001-01-01 01:00:00        1      1  2001          1           1           1
# 2001-01-01 02:00:00        1      1  2001          1           1           1
# 2001-01-01 03:00:00        1      1  2001          1           1           1
# 2001-01-01 04:00:00        1      1  2001          1           1           1
# ...                      ...    ...   ...        ...         ...         ...
# 2024-05-11 20:00:00        2      5  2024        132          11          19
# 2024-05-11 21:00:00        2      5  2024        132          11          19
# 2024-05-11 22:00:00        2      5  2024        132          11          19
# 2024-05-11 23:00:00        2      5  2024        132          11          19
# 2024-05-12 00:00:00        2      5  2024        133          12          19
#
#                      date_offset season  holiday
# date
# 2001-01-01 00:00:00         1081      3        1
# 2001-01-01 01:00:00         1081      3        1
# 2001-01-01 02:00:00         1081      3        1
# 2001-01-01 03:00:00         1081      3        1
# 2001-01-01 04:00:00         1081      3        1
# ...                          ...    ...      ...
# 2024-05-11 20:00:00          191      0        1
# 2024-05-11 21:00:00          191      0        1
# 2024-05-11 22:00:00          191      0        1
# 2024-05-11 23:00:00          191      0        1
# 2024-05-12 00:00:00          192      0        1
#
# [204193 rows x 13 columns]

# %%
plt.figure(figsize=(17, 7))
plt.plot(y_train, label='Training Set')
plt.plot(y_test, label='Test Set')
plt.legend()
plt.show()

# %%
# train = df_n.loc[df_n.index < '01-01-2018']
# test = df_n.loc[df_n.index >= '01-01-2018']
# train

# %%
# train = create_features(train)
# test = create_features(test)

# FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year']
# TARGET = 'Crime Count'

# X_train = train[FEATURES]
# y_train = train[TARGET]

# X_test = test[FEATURES]
# y_test = test[TARGET]
# train.info()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
sns.heatmap(df_n.corr(),annot=True, cmap='coolwarm')
# df_n.corr()
# Out:
# <Axes: >

# %% [markdown]
# #XG Boost Regression

# %%
from xgboost import XGBRegressor


# xgb = XGBRegressor(  objective='reg:squarederror',
#                       enable_categorical=True)

xgb = XGBRegressor( base_score=0.5, booster= 'gbtree',objective='reg:squarederror',
                       n_estimators=346,
                   early_stopping_rounds=10,
                     max_depth=11,
                     learning_rate =0.0091, enable_categorical=True)

xgb.fit(X_train, y_train,
       eval_set=[(X_train, y_train), (X_test, y_test)],
         verbose=10)
# Out:
# [0]	validation_0-rmse:48.54634	validation_1-rmse:30.01401
# [10]	validation_0-rmse:44.45554	validation_1-rmse:27.31191
# [20]	validation_0-rmse:40.73230	validation_1-rmse:24.87368
# [30]	validation_0-rmse:37.34464	validation_1-rmse:22.67449
# [40]	validation_0-rmse:34.26428	validation_1-rmse:20.69364
# [50]	validation_0-rmse:31.46467	validation_1-rmse:18.91892
# [60]	validation_0-rmse:28.92228	validation_1-rmse:17.33523
# [70]	validation_0-rmse:26.61534	validation_1-rmse:15.91897
# [80]	validation_0-rmse:24.52444	validation_1-rmse:14.66182
# [90]	validation_0-rmse:22.63086	validation_1-rmse:13.55274
# [100]	validation_0-rmse:20.91864	validation_1-rmse:12.58075
# [110]	validation_0-rmse:19.37231	validation_1-rmse:11.73622
# [120]	validation_0-rmse:17.97816	validation_1-rmse:11.00828
# [130]	validation_0-rmse:16.72322	validation_1-rmse:10.38242
# [140]	validation_0-rmse:15.59631	validation_1-rmse:9.85636
# [150]	validation_0-rmse:14.58636	validation_1-rmse:9.41950
# [160]	validation_0-rmse:13.68327	validation_1-rmse:9.05980
# [170]	validation_0-rmse:12.87740	validation_1-rmse:8.76724
# [180]	validation_0-rmse:12.16096	validation_1-rmse:8.53343
# [190]	validation_0-rmse:11.52565	validation_1-rmse:8.35129
# [200]	validation_0-rmse:10.96369	validation_1-rmse:8.21161
# [210]	validation_0-rmse:10.46848	validation_1-rmse:8.11052
# [220]	validation_0-rmse:10.03296	validation_1-rmse:8.03806
# [230]	validation_0-rmse:9.65055	validation_1-rmse:7.98972
# [240]	validation_0-rmse:9.31519	validation_1-rmse:7.96329
# [250]	validation_0-rmse:9.02286	validation_1-rmse:7.95088
# [260]	validation_0-rmse:8.76612	validation_1-rmse:7.95072
# [264]	validation_0-rmse:8.67240	validation_1-rmse:7.95253
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=10,
#              enable_categorical=True, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.0091, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=11, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=346, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
results = xgb.evals_result()
val_error_test = results['validation_1']['rmse']
val_error_train = results['validation_0']['rmse']

# %%
plt.plot(val_error_test)
plt.plot(val_error_train, color='orange')
plt.legend(['Testing rmse', 'Training rmse'])
plt.xlabel('Boosting rounds')
plt.ylabel('RMSE')
plt.show()

# %%
imp = pd.DataFrame(data=xgb.feature_importances_,
             index=xgb.feature_names_in_,
             columns=['importance'])
imp.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
test = pd.DataFrame(y_test)
test['prediction'] = xgb.predict(X_test)
train = pd.DataFrame(y_train)
train['prediction'] = xgb.predict(X_train)

# unscaled = pd.DataFrame(scaler.inverse_transform(test),columns=test.columns)
# print(test)
# print(unscaled)
plt.figure(figsize=(10,5))
# df_n = df_n.merge(forest.predict(X_test), how='left', left_index=True, right_index=True)
plt.plot(df_year,zorder=1)
plt.scatter(test.index, test['prediction'], color='orange', zorder=2)

plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.xlabel('Time')
plt.show()

# %%
test_n = test.loc[(test.index >= start) & (test.index <= end)]

plt.figure(figsize=(17,7))
plt.plot(test_n['Crime Count'])
plt.plot(test_n.index, test_n['prediction'], color='orange')
plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
train_rmse = np.sqrt(train_mse)
train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
train_r2 = r2_score(train['Crime Count'], train['prediction'])

print("The R-squared of the model on the training set :", train_r2)
print(f"The mean squared error of the model on the training set : {train_mse:.3f}")
print(f"The root mean squared error of the model on the training set : {train_rmse:.3f}")
print(f"The mean absolute error of the model on the training set : {train_mae:.3f}\n")


test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
test_r2 = r2_score(test['Crime Count'], test['prediction'])


print("The R-squared of the model on testing set is:", test_r2)
print(f"The mean squared error of the model on the testing set : {test_mse:.3f}")
print(f"The root mean squared error of the model on the testing set : {test_rmse:.3f}")
print(f"The mean absolute error of the model on the testing set : {test_mae:.3f}")
# Out:
# The R-squared of the model on the training set : 0.8365122098623762
# The mean squared error of the model on the training set : 79.021
# The root mean squared error of the model on the training set : 8.889
# The mean absolute error of the model on the training set : 6.628
#
# The R-squared of the model on testing set is: 0.6107412212383021
# The mean squared error of the model on the testing set : 63.195
# The root mean squared error of the model on the testing set : 7.950
# The mean absolute error of the model on the testing set : 5.830

# %%
tr_acc=xgb.score(X_train,y_train)*100
te_acc=xgb.score(X_test,y_test)*100
print(f'Training R2 Score: {tr_acc:.2f} %')
print(f'Testing R2 Score: {te_acc:.2f} %')
# Out:
# Training R2 Score: 83.65 %
# Testing R2 Score: 61.07 %

# %%
typ = '10D'
df_month = y_test.resample(typ).size().to_frame('Crime Count')
df_month=df_month[1:]
gen = df_month.drop(['Crime Count'], axis=1)
df_month = df_month.index

# %%
test = pd.DataFrame(y_test)
test['prediction'] = xgb.predict(X_test)

generalization = []
for x in df_month:
  test_new = test.loc[(test.index>='2017-05-09 15:00:00') & (test.index <= x)]
  test_r2 = r2_score(test_new['Crime Count'], test_new['prediction'])*100
  generalization.append(round(test_r2, 2))

# %%
gen['generalization'] = generalization

# %%
gen
# Out:
#             generalization
# date
# 2017-05-19           68.26
# 2017-05-29           69.70
# 2017-06-08           68.80
# 2017-06-18           68.07
# 2017-06-28           68.13
# ...                    ...
# 2024-04-02           61.08
# 2024-04-12           61.07
# 2024-04-22           61.07
# 2024-05-02           61.07
# 2024-05-12           61.07
#
# [256 rows x 1 columns]

# %%
# plt.figure(figsize=(17,7))
plt.plot(gen.index, gen['generalization'])
plt.legend(['Generalization'])
plt.title('Generalization on increasing Test Data by 10 days')
plt.ylabel('R2_score(%)')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# #Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# Create a decision tree regressor
model = DecisionTreeRegressor(max_features=0.7,
                     max_depth=13, min_samples_leaf=20)
np.random.seed(0)
# Fit the model to the data
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=13, max_features=0.7, min_samples_leaf=20)

# %%
feature_names = X_train.columns
imp = pd.DataFrame(data=model.feature_importances_,
             index=feature_names,
             columns=['importance'])
imp.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
test = pd.DataFrame(y_test)
test['prediction'] = model.predict(X_test)
train = pd.DataFrame(y_train)
train['prediction'] = model.predict(X_train)

# %%
# unscaled = pd.DataFrame(scaler.inverse_transform(test),columns=test.columns)
# print(test)
# print(unscaled)
plt.figure(figsize=(17,7))
# df_n = df_n.merge(forest.predict(X_test), how='left', left_index=True, right_index=True)
plt.plot(df_year,zorder=1)
plt.scatter(test.index, test['prediction'], color='orange', zorder=2)

plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
test
# Out:
#                      Crime Count  prediction
# date
# 2017-05-09 15:00:00           43   42.561644
# 2017-05-09 16:00:00           39   42.561644
# 2017-05-09 17:00:00           47   42.561644
# 2017-05-09 18:00:00           45   42.561644
# 2017-05-09 19:00:00           47   42.561644
# ...                          ...         ...
# 2024-05-11 20:00:00           31   37.220096
# 2024-05-11 21:00:00           30   37.220096
# 2024-05-11 22:00:00           32   37.220096
# 2024-05-11 23:00:00           30   32.652174
# 2024-05-12 00:00:00           16   40.194444
#
# [61258 rows x 2 columns]

# %%
# start = '2007-07-20'
# end = '2007-07-30'
test_n = test.loc[(test.index >= start) & (test.index <= end)]

plt.figure(figsize=(17,7))
plt.plot(test_n['Crime Count'])
plt.plot(test_n.index, test_n['prediction'], color='orange')
plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
train_rmse = np.sqrt(train_mse)
train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
train_r2 = r2_score(train['Crime Count'], train['prediction'])

print("The R-squared of the model on the training set :", train_r2)
print(f"The root mean squared error of the model on the training set : {train_rmse:.3f}")
print(f"The mean absolute error of the model on the training set : {train_mae:.3f}\n")

test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
test_r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model on testing set is:", test_r2)
print(f"The root mean squared error of the model on the testing set : {test_rmse:.3f}")
print(f"The mean absolute error of the model on the testing set : {test_mae:.3f}")
# Out:
# The R-squared of the model on the training set : 0.8465915657230483
# The root mean squared error of the model on the training set : 8.611
# The mean absolute error of the model on the training set : 6.139
#
# The R-squared of the model on testing set is: 0.5263531949860248
# The root mean squared error of the model on the testing set : 8.769
# The mean absolute error of the model on the testing set : 6.527

# %%
tr_acc=train_r2*100
te_acc=test_r2*100
print(f'Training R2 Score: {tr_acc:.2f} %')
print(f'Testing R2 Score: {te_acc:.2f} %')
# Out:
# Training R2 Score: 84.66 %
# Testing R2 Score: 52.64 %

# %%
typ = '10D'
df_month = y_test.resample(typ).size().to_frame('Crime Count')
df_month=df_month[1:]
gen = df_month.drop(['Crime Count'], axis=1)
df_month = df_month.index

# %%
test = pd.DataFrame(y_test)
test['prediction'] = model.predict(X_test)

generalization = []
for x in df_month:
  test_new = test.loc[(test.index>='2017-05-09 15:00:00') & (test.index <= x)]
  test_r2 = r2_score(test_new['Crime Count'], test_new['prediction'])*100
  generalization.append(round(test_r2, 2))

# %%
gen['generalization'] = generalization

# %%
# plt.figure(figsize=(17,7))
plt.plot(gen.index, gen['generalization'])
plt.legend(['Generalization'])
plt.title('Generalization on increasing Test Data by 10 days')
plt.ylabel('R2_score(%)')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# #Random Forest Regression (4min)

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor( max_features=0.7,
                n_estimators=346,
                     max_depth=13, min_samples_leaf=20
                     )
np.random.seed(0)
forest.fit(X_train, y_train)
forest.score(X_test,y_test)
# Out:
# 0.5606111844390347

# %%
# import joblib

# file = open("/content/drive/Othercomputers/My laptop/php/Crime_Database/chicago_rndforest_model.joblib", "wb")
# joblib.dump(forest,file)

# %%
# import joblib

# file = open("/content/drive/Othercomputers/My laptop/php/Crime_Database/chicago_rndforest_model.joblib", "rb")
# forest = joblib.load(file)

# %%
forest.score(X_train,y_train)
# Out:
# 0.8576114274927026

# %%
forest.score(X_test,y_test)
# Out:
# 0.5606111844390347

# %%
imp = pd.DataFrame(data=forest.feature_importances_,
             index=forest.feature_names_in_,
             columns=['importance'])

imp.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
# df_n = create_features(df_year)
test = pd.DataFrame(y_test)
test['prediction'] = forest.predict(X_test)
train = pd.DataFrame(y_train)
train['prediction'] = forest.predict(X_train)
# unscaled = pd.DataFrame(scaler.inverse_transform(test),columns=test.columns)
# print(test)
# print(unscaled)
plt.figure(figsize=(17,7))
# df_n = df_n.merge(forest.predict(X_test), how='left', left_index=True, right_index=True)
plt.plot(df_year,zorder=1)
plt.scatter(test.index, test['prediction'], color='orange', zorder=2)

plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
test_n = test.loc[(test.index >= start) & (test.index <= end)]

plt.figure(figsize=(17,7))
plt.plot(test_n['Crime Count'])
plt.scatter(test_n.index, test_n['prediction'], color='orange')
plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
train_rmse = np.sqrt(train_mse)
train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
train_r2 = r2_score(train['Crime Count'], train['prediction'])

print("The R-squared of the model on the train set :", train_r2)
print(f"The root mean squared error of the model on the train set : {train_rmse:.3f}")
print(f"The mean absolute error of the model on the train set : {train_mae:.3f}\n")

test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
test_r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model on the test set is:", test_r2)
print(f"The root mean squared error of the model on the test set : {test_rmse:.3f}")
print(f"The mean absolute error of the model on the test set : {test_mae:.3f}")
# Out:
# The R-squared of the model on the train set : 0.8576114274927026
# The root mean squared error of the model on the train set : 8.296
# The mean absolute error of the model on the train set : 5.943
#
# The R-squared of the model on the test set is: 0.5606111844390347
# The root mean squared error of the model on the test set : 8.446
# The mean absolute error of the model on the test set : 6.413

# %%
tr_acc=forest.score(X_train,y_train)*100
te_acc=forest.score(X_test,y_test)*100
print(f'R2 score on training: {tr_acc:.2f} %')
print(f'R2 score on testing: {te_acc:.2f} %')
# Out:
# R2 score on training: 85.76 %
# R2 score on testing: 56.06 %

# %%
typ = '10D'
df_month = y_test.resample(typ).size().to_frame('Crime Count')
df_month=df_month[1:]
gen = df_month.drop(['Crime Count'], axis=1)
df_month = df_month.index

# %%
test = pd.DataFrame(y_test)
test['prediction'] = forest.predict(X_test)

generalization = []
for x in df_month:
  test_new = test.loc[(test.index>='2017-05-09 15:00:00') & (test.index <= x)]
  test_r2 = r2_score(test_new['Crime Count'], test_new['prediction'])*100
  generalization.append(round(test_r2, 2))

# %%
gen['generalization'] = generalization

# %%
# plt.figure(figsize=(17,7))
plt.plot(gen.index, gen['generalization'])
plt.legend(['Generalization'])
plt.title('Generalization on increasing Test Data by 10 days')
plt.ylabel('R2_score(%)')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# #LGBM Regression

# %%
import lightgbm as lgb

# Create the dataset for LightGBM
# lgb_train = lgb.Dataset()

np.random.seed(0)
model = lgb.LGBMRegressor(force_col_wise=True, n_estimators=400,
                     max_depth=14,
                     learning_rate =0.01, num_leaves=150, verbose=-1)

# Train the model
model.fit(X_train, y_train, eval_metric='rmse', eval_set=[(X_train, y_train)])
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# LGBMRegressor(force_col_wise=True, learning_rate=0.01, max_depth=14,
#               n_estimators=400, num_leaves=150, verbose=-1)

# %%
print(model.get_params())
# Out:
# {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.01, 'max_depth': 14, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 400, 'n_jobs': None, 'num_leaves': 150, 'objective': None, 'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'subsample': 1.0, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'force_col_wise': True, 'verbose': -1}

# %%
imp = pd.DataFrame(data=model.feature_importances_,
             index=model.feature_name_,
             columns=['importance'])
imp.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
test = pd.DataFrame(y_test)
test['prediction'] = model.predict(X_test)
train = pd.DataFrame(y_train)
train['prediction'] = model.predict(X_train)

plt.figure(figsize=(10,5))

plt.plot(df_year,zorder=1)
plt.scatter(test.index, test['prediction'], color='orange', zorder=2)

plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.xlabel('Time')
plt.show()

# %%
test_n = test.loc[(test.index >= start) & (test.index <= end)]

plt.figure(figsize=(17,7))
plt.plot(test_n['Crime Count'])
plt.plot(test_n.index, test_n['prediction'], color='orange')
plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
train_rmse = np.sqrt(train_mse)
train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
train_r2 = r2_score(train['Crime Count'], train['prediction'])

print("The R-squared of the model on the training set :", train_r2)
print(f"The root mean squared error of the model on the training set : {train_rmse:.3f}")
print(f"The mean absolute error of the model on the training set : {train_mae:.3f}\n")

test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
test_r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model on testing set is:", test_r2)
print(f"The root mean squared error of the model on the testing set : {test_rmse:.3f}")
print(f"The mean absolute error of the model on the testing set : {test_mae:.3f}")
# Out:
# The R-squared of the model on the training set : 0.8706773926852028
# The root mean squared error of the model on the training set : 7.906
# The mean absolute error of the model on the training set : 5.986
#
# The R-squared of the model on testing set is: 0.553212974337643
# The root mean squared error of the model on the testing set : 8.517
# The mean absolute error of the model on the testing set : 6.414

# %%
tr_acc=model.score(X_train,y_train)*100
te_acc=model.score(X_test,y_test)*100
print(f'Training accuracy: {tr_acc:.2f} %')
print(f'Testing accuracy: {te_acc:.2f} %')
# Out:
# Training accuracy: 87.07 %
# Testing accuracy: 55.32 %

# %%
typ = '10D'
df_month = y_test.resample(typ).size().to_frame('Crime Count')
df_month=df_month[1:]
gen = df_month.drop(['Crime Count'], axis=1)
df_month = df_month.index

# %%
test = pd.DataFrame(y_test)
test['prediction'] = model.predict(X_test)

generalization = []
for x in df_month:
  test_new = test.loc[(test.index>='2017-05-09 15:00:00') & (test.index <= x)]
  test_r2 = r2_score(test_new['Crime Count'], test_new['prediction'])*100
  generalization.append(round(test_r2, 2))

# %%
gen['generalization'] = generalization

# %%
# plt.figure(figsize=(17,7))
plt.plot(gen.index, gen['generalization'])
plt.legend(['Generalization'])
plt.title('Generalization on increasing Test Data by 10 days')
plt.ylabel('R2_score(%)')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# #Linear Regression

# %%
from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import StandardScaler



model = LinearRegression()
np.random.seed(0)
model.fit(X_train, y_train)

# Make predictions

# x_scaled = sc_X.fit_transform(X_test)
# y_pred = sc_y.inverse_transform(model.predict(x_scaled).reshape(-1,1))
# y_test_pred = sc_y.inverse_transform(model.predict(sc_X.transform(X_test)).reshape(-1,1))
# print(f"The predicted number of crimes in {state} in {start} to {end} is {y_pred.flatten()}")

# X_train, y_train

y_test_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_test_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_test_pred)
r2 = r2_score(y_test, y_test_pred)

print("The R-squared of the model is:", r2)
print(f"The root mean squared error of the model on the testing set is {rmse:.0f}")
print(f"The mean absolute error of the model on the testing set is {mae:.0f}")
# Out:
# The R-squared of the model is: -0.3041006442801697
# The root mean squared error of the model on the testing set is 15
# The mean absolute error of the model on the testing set is 10

# %%
test = pd.DataFrame(y_test)
test['prediction'] = model.predict(X_test)
train = pd.DataFrame(y_train)
train['prediction'] = model.predict(X_train)

plt.figure(figsize=(9,4))
plt.plot(df_n['Crime Count'], color="blue", label="Actual")
plt.plot(X_test.index, y_test_pred, color="red"  )
# plt.plot(x, y_pred , color="red", label="Performance")
# # plt.plot(np.arange(start, end), y_pred_svr, color="red")
plt.xlabel("Year")
plt.ylabel("Total IPC Crimes")

plt.title(f"Crime Prediction in {state} using Linear Regression")
plt.legend()
plt.show()

# %%
train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
train_rmse = np.sqrt(train_mse)
train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
train_r2 = r2_score(train['Crime Count'], train['prediction'])

print("The R-squared of the model on the training set :", train_r2)
print(f"The root mean squared error of the model on the training set : {train_rmse:.3f}")
print(f"The mean absolute error of the model on the training set : {train_mae:.3f}\n")

test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
test_r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model on testing set is:", test_r2)
print(f"The root mean squared error of the model on the testing set : {test_rmse:.3f}")
print(f"The mean absolute error of the model on the testing set : {test_mae:.3f}")
# Out:
# The R-squared of the model on the training set : 0.4243939774017923
# The root mean squared error of the model on the training set : 16.680
# The mean absolute error of the model on the training set : 12.258
#
# The R-squared of the model on testing set is: -0.3041006442801697
# The root mean squared error of the model on the testing set : 14.550
# The mean absolute error of the model on the testing set : 10.461

# %%
tr_acc=model.score(X_train,y_train)*100
te_acc=model.score(X_test,y_test)*100
print(f'Training R2_score {tr_acc:.2f} %')
print(f'Testing R2_score: {te_acc:.2f} %')
# Out:
# Training R2_score 42.44 %
# Testing R2_score: -30.41 %

# %%
test_n = test.loc[(test.index >= start) & (test.index <= end)]

plt.figure(figsize=(17,7))
plt.plot(test_n['Crime Count'])
plt.plot(test_n.index, test_n['prediction'], color='orange')
plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %% [markdown]
# #Polynomial Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
# Create and fit a polynomial regression model of degree 3
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X_train)
# y_scaled = scaler.fit_transform(y_train.values.reshape(-1,1))
# X_scaled = pd.DataFrame(X_scaled, columns = X_train.columns)
model_poly = make_pipeline(PolynomialFeatures(degree=3), LinearRegression())

# poly = PolynomialFeatures(degree=2)
# X_poly = poly.fit_transform(X_train)

# model_poly = LinearRegression()
model_poly.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=3)),
#                 ('linearregression', LinearRegression())])

# %%
test = pd.DataFrame(y_test)
test['prediction'] = model_poly.predict(X_test)
train = pd.DataFrame(y_train)
train['prediction'] = model_poly.predict(X_train)


mse = mean_squared_error(test['Crime Count'], test['prediction'])
rmse = np.sqrt(mse)
mae = mean_absolute_error(test['Crime Count'], test['prediction'])
r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model is:", r2)
print(f"The root mean squared error of the model on the testing set is {rmse:.0f}")
print(f"The mean absolute error of the model on the testing set is {mae:.0f}")
# Out:
# The R-squared of the model is: -0.22949519496951676
# The root mean squared error of the model on the testing set is 14
# The mean absolute error of the model on the testing set is 11

# %%
plt.figure(figsize=(10,5))

plt.scatter(df_year.index, df_year['Crime Count'],zorder=1)
plt.scatter(test.index, test['prediction'], color='orange', zorder=2)

plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.xlabel('Time')
plt.show()

# %%
plt.figure(figsize=(9,4))
plt.plot(test['Crime Count'].head(500), color="blue", label="Actual")
plt.plot(test['prediction'].head(500), color="orange")
plt.xticks(rotation=45)
plt.show()

# %%
train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
train_rmse = np.sqrt(train_mse)
train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
train_r2 = r2_score(train['Crime Count'], train['prediction'])

print("The R-squared of the model on the training set :", train_r2)
print(f"The root mean squared error of the model on the training set : {train_rmse:.3f}")
print(f"The mean absolute error of the model on the training set : {train_mae:.3f}\n")

test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
test_r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model on testing set is:", test_r2)
print(f"The root mean squared error of the model on the testing set : {test_rmse:.3f}")
print(f"The mean absolute error of the model on the testing set : {test_mae:.3f}")
# Out:
# The R-squared of the model on the training set : 0.6701543203752001
# The root mean squared error of the model on the training set : 12.627
# The mean absolute error of the model on the training set : 9.261
#
# The R-squared of the model on testing set is: -0.22949519496951676
# The root mean squared error of the model on the testing set : 14.128
# The mean absolute error of the model on the testing set : 10.538

# %%
tr_acc=model_poly.score(X_train,y_train)*100
te_acc=model_poly.score(X_test,y_test)*100
print(f'Training accuracy: {tr_acc:.2f} %')
print(f'Testing accuracy: {te_acc:.2f} %')
# Out:
# Training accuracy: 67.02 %
# Testing accuracy: -22.95 %
