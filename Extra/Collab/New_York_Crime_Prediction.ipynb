# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Dataset Resampling

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/Othercomputers/My laptop/php/Crime_Database/New_York_crime_2001_2023.csv",on_bad_lines='skip')

# %%
# df_x = df.groupby('Primary Type')

# %%
# df_x = df_x.get_group('ROBBERY')

# %%
df
# Out:
#        cmplnt_num                      ofns_desc           prem_typ_desc  \
# 0       276064587                        FORGERY                  (null)
# 1       270189205  OFF. AGNST PUB ORD SENSBLTY &  RESIDENCE - APT. HOUSE
# 2       261406434  OFF. AGNST PUB ORD SENSBLTY &         RESIDENCE-HOUSE
# 3       267991366                           RAPE         RESIDENCE-HOUSE
# 4       267676735                     SEX CRIMES  RESIDENCE - APT. HOUSE
# ...           ...                            ...                     ...
# 554964  279766994                  HARRASSMENT 2         RESIDENCE-HOUSE
# 554965  279767324                  HARRASSMENT 2         RESIDENCE-HOUSE
# 554966  279763418        MISCELLANEOUS PENAL LAW                  STREET
# 554967  279766995                  HARRASSMENT 2         RESIDENCE-HOUSE
# 554968  279766997                  HARRASSMENT 2         RESIDENCE-HOUSE
#
#          boro_nm vic_sex susp_sex   latitude  longitude                 date
# ...

# %%
df
# Out:
#        cmplnt_num                      ofns_desc           prem_typ_desc  \
# 0       276064587                        FORGERY                  (null)
# 1       270189205  OFF. AGNST PUB ORD SENSBLTY &  RESIDENCE - APT. HOUSE
# 2       261406434  OFF. AGNST PUB ORD SENSBLTY &         RESIDENCE-HOUSE
# 3       267991366                           RAPE         RESIDENCE-HOUSE
# 4       267676735                     SEX CRIMES  RESIDENCE - APT. HOUSE
# ...           ...                            ...                     ...
# 554964  279766994                  HARRASSMENT 2         RESIDENCE-HOUSE
# 554965  279767324                  HARRASSMENT 2         RESIDENCE-HOUSE
# 554966  279763418        MISCELLANEOUS PENAL LAW                  STREET
# 554967  279766995                  HARRASSMENT 2         RESIDENCE-HOUSE
# 554968  279766997                  HARRASSMENT 2         RESIDENCE-HOUSE
#
#          boro_nm vic_sex susp_sex   latitude  longitude                 date
# ...

# %%
df = df.replace('(null)', None)

# %%
df.isnull().sum()
# Out:
# cmplnt_num           0
# ofns_desc           17
# prem_typ_desc    22193
# boro_nm           1019
# vic_sex              0
# susp_sex         72112
# latitude             0
# longitude            0
# date                 0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()

# %%
df = df.set_index('date')

# %%
df.index = pd.to_datetime(df.index,format = '%Y-%m-%dT%H:%M:%S')

# %%
df
# Out:
#                     cmplnt_num                      ofns_desc  \
# date
# 2001-02-20 10:00:00  276064587                        FORGERY
# 2001-04-01 00:00:00  270189205  OFF. AGNST PUB ORD SENSBLTY &
# 2001-04-21 16:35:00  261406434  OFF. AGNST PUB ORD SENSBLTY &
# 2001-05-01 06:00:00  267991366                           RAPE
# 2001-06-01 15:00:00  267676735                     SEX CRIMES
# ...                        ...                            ...
# 2023-12-31 21:20:00  279766994                  HARRASSMENT 2
# 2023-12-31 18:50:00  279767324                  HARRASSMENT 2
# 2023-12-31 21:40:00  279763418        MISCELLANEOUS PENAL LAW
# 2023-12-31 18:35:00  279766995                  HARRASSMENT 2
# 2023-12-31 02:10:00  279766997                  HARRASSMENT 2
#
#                               prem_typ_desc   boro_nm vic_sex susp_sex  \
# date
# 2001-02-20 10:00:00                  (null)  BROOKLYN       F   (null)
# ...

# %%
df[df.index<'2023']
# Out:
#                     cmplnt_num                       ofns_desc  \
# date
# 2001-02-20 10:00:00  276064587                         FORGERY
# 2001-04-01 00:00:00  270189205   OFF. AGNST PUB ORD SENSBLTY &
# 2001-04-21 16:35:00  261406434   OFF. AGNST PUB ORD SENSBLTY &
# 2001-05-01 06:00:00  267991366                            RAPE
# 2001-06-01 15:00:00  267676735                      SEX CRIMES
# ...                        ...                             ...
# 2022-12-31 23:00:00  262102320    ASSAULT 3 & RELATED OFFENSES
# 2022-12-31 18:00:00  261336838  GRAND LARCENY OF MOTOR VEHICLE
# 2022-12-31 00:00:00  261779817                   HARRASSMENT 2
# 2022-12-31 15:39:00  261357527                     THEFT-FRAUD
# 2022-12-31 23:00:00  261545028                   GRAND LARCENY
#
#                               prem_typ_desc   boro_nm vic_sex susp_sex  \
# date
# 2001-02-20 10:00:00                  (null)  BROOKLYN       F   (null)
# ...

# %%
typ = 'h'
df_year = df.resample(typ).size().to_frame('Crime Count')
d_type = 'datetime64['+typ+']'
df_year

# %%
plt.figure(figsize=(9,4))
plt.plot(df_year.index, df_year['Crime Count'])
plt.title("Crime Count Per Hour")
plt.xlabel("Years")
plt.ylabel("Number of Crimes")

# %%
df_year = df_year.reset_index()
df_year

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import seaborn as sns


from sklearn.preprocessing import StandardScaler

# %%
# Read data

state = 'Chicago'
start = '2001'
end = '2040'

# Split the data into input and output variables
X = df_year['date'].values.reshape(-1, 1).astype(d_type) # Input variable
y = df_year["Crime Count"].values.reshape(-1, 1)  # Output variable

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, shuffle = False)

# from sklearn.preprocessing import StandardScaler

sc_X = StandardScaler()
sc_y = StandardScaler()
X_train = sc_X.fit_transform(X_train)
y_train = sc_y.fit_transform(y_train)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
sns.heatmap(df_n.corr(),annot=True, cmap='coolwarm')
# df_n.corr()

# %%
train_X = train_df.drop('Crime Count',axis=1)
train_y = train_df['Crime Count']

test_X = test_df.drop('Crime Count',axis=1)
test_y = test_df['Crime Count']
X_n = df_year.drop('Crime Count',axis=1)
y_n = df_year['Crime Count']

# %%
df_year.to_csv('/content/drive/Othercomputers/My laptop/php/Crime_Database/Chicago_2001_2023.csv')

# %% [markdown]
# #Data Preparation

# %%
import pandas as pd
import matplotlib.pyplot as plt


df_year=pd.read_csv('/content/drive/Othercomputers/My laptop/php/Crime_Database/New_York_2001_2023.csv')

# %%
df_year
# Out:
#                      date  Crime Count
# 0     2023-01-01 00:00:00          170
# 1     2023-01-01 01:00:00           88
# 2     2023-01-01 02:00:00           85
# 3     2023-01-01 03:00:00           79
# 4     2023-01-01 04:00:00           69
# ...                   ...          ...
# 8755  2023-12-31 19:00:00           41
# 8756  2023-12-31 20:00:00           33
# 8757  2023-12-31 21:00:00           42
# 8758  2023-12-31 22:00:00           33
# 8759  2023-12-31 23:00:00           14
#
# [8760 rows x 2 columns]

# %%
df_year = df_year.set_index('date')

# %%
df_year.index =  pd.to_datetime(df_year.index,format = '%Y-%m-%d %H:%M:%S')
df_year = df_year[(df_year.index >='2012') & (df_year.index <='2024') ]

# %%
start = '2023-10-20'
end = '2023-10-30'

# %%
df_year
# Out:
#                      Crime Count
# date
# 2023-01-01 00:00:00          170
# 2023-01-01 01:00:00           88
# 2023-01-01 02:00:00           85
# 2023-01-01 03:00:00           79
# 2023-01-01 04:00:00           69
# ...                          ...
# 2023-12-31 19:00:00           41
# 2023-12-31 20:00:00           33
# 2023-12-31 21:00:00           42
# 2023-12-31 22:00:00           33
# 2023-12-31 23:00:00           14
#
# [8760 rows x 1 columns]

# %% [markdown]
# ###Features Creation

# %%
from datetime import date, timedelta
import pandas as pd
import holidays

# Create a list of dates from 1 Jan 2023 to 1 Jan 2024
start_date = df_year.head(1).index.date[0]
end_date = df_year.tail(1).index.date[0]

delta = timedelta(days=1)
dates = []
while start_date <= end_date:
    dates.append(start_date)
    start_date += delta
dates.append(start_date)
# Create a DataFrame
df_h = pd.DataFrame(dates, columns=['Date'])

# Get US holidays
us_holidays = holidays.US(state='NY')

# Create a column for holidays
df_h['Holiday'] = df_h['Date'].apply(lambda x: us_holidays.get(x))
df_h.head()
# Out:
#          Date                    Holiday
# 0  2023-01-01             New Year's Day
# 1  2023-01-02  New Year's Day (observed)
# 2  2023-01-03                       None
# 3  2023-01-04                       None
# 4  2023-01-05                       None

# %%
df_h['Date'] = pd.to_datetime(df_h['Date'], format = '%Y-%m-%d')

df_h.set_index('Date',inplace=True)

df_h[df_h['Holiday'].isnull()] = 0
df_h[df_h['Holiday'] != 0] = 1

df_h = df_h.resample('H').ffill()
df_h
# Out:
#                     Holiday
# Date
# 2023-01-01 00:00:00       1
# 2023-01-01 01:00:00       1
# 2023-01-01 02:00:00       1
# 2023-01-01 03:00:00       1
# 2023-01-01 04:00:00       1
# ...                     ...
# 2023-12-31 20:00:00       0
# 2023-12-31 21:00:00       0
# 2023-12-31 22:00:00       0
# 2023-12-31 23:00:00       0
# 2024-01-01 00:00:00       1
#
# [8761 rows x 1 columns]

# %%
df_h = df_h['Holiday'].astype('int32')
df_h = df_h.to_frame('Holiday')

# %%
# weekday_mapping = {
#     'Monday': 1,
#     'Tuesday': 2,
#     'Wednesday': 3,
#     'Thursday': 4,
#     'Friday': 5,
#     'Saturday': 6,
#     'Sunday': 7
# }

def create_features(df_year):

    df = df_year.copy()

    df['date'] = df.index
    df['hour'] = df['date'].dt.hour
    df['dayofweek'] = df['date'].dt.dayofweek
    # df['weekday'] = df['date'].dt.day_name()
    # df['weekday'] = df['weekday'].map(weekday_mapping)
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['weekofyear'] = df['date'].dt.isocalendar().week
    df['date_offset'] = (df.date.dt.month*100 + df.date.dt.day - 320)%1300

    df['season'] = pd.cut(df['date_offset'], [0, 300, 602, 900, 1300],
                          labels=[0, 1, 2, 3] # 0 = 'Spring', 1 = 'Summer', 2 = 'Fall', 3 = 'Winter'
                          )
    df['holiday'] = df_h['Holiday']
    df=df.dropna()
    print(df)
    return df

FEATURES = ['hour','dayofweek','quarter','month','year',
          'dayofyear','dayofmonth','weekofyear',
           'season', 'holiday']
TARGET = 'Crime Count'

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import StandardScaler


# def error(y_true, y_pred):
#   y_pred = np.array(y_pred)
#   y_true = np.array(y_true)
#   error = np.abs(y_true - y_pred) / y_true
#   return np.mean(error) * 100

# def mean_absolute_percentage_error(y_true, y_pred):
#     """Calculates MAPE given y_true and y_pred"""
#     y_true, y_pred = np.array(y_true), np.array(y_pred)
#     return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
state = 'New York'

df_n = create_features(df_year)
# df_n
# Out:
#                      Crime Count                date  hour  dayofweek  \
# date
# 2023-01-01 00:00:00          170 2023-01-01 00:00:00     0          6
# 2023-01-01 01:00:00           88 2023-01-01 01:00:00     1          6
# 2023-01-01 02:00:00           85 2023-01-01 02:00:00     2          6
# 2023-01-01 03:00:00           79 2023-01-01 03:00:00     3          6
# 2023-01-01 04:00:00           69 2023-01-01 04:00:00     4          6
# ...                          ...                 ...   ...        ...
# 2023-12-31 19:00:00           41 2023-12-31 19:00:00    19          6
# 2023-12-31 20:00:00           33 2023-12-31 20:00:00    20          6
# 2023-12-31 21:00:00           42 2023-12-31 21:00:00    21          6
# 2023-12-31 22:00:00           33 2023-12-31 22:00:00    22          6
# 2023-12-31 23:00:00           14 2023-12-31 23:00:00    23          6
#
#                      quarter  month  year  dayofyear  dayofmonth  weekofyear  \
# date
# ...

# %% [markdown]
# ###Train/Test Split

# %%
X = df_n[FEATURES]# Input variable
y = df_n[TARGET] # Output variable
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=None, shuffle = False)

# %%
X_train
# Out:
#                      hour  dayofweek  quarter  month  year  dayofyear  \
# date
# 2023-01-01 00:00:00     0          6        1      1  2023          1
# 2023-01-01 01:00:00     1          6        1      1  2023          1
# 2023-01-01 02:00:00     2          6        1      1  2023          1
# 2023-01-01 03:00:00     3          6        1      1  2023          1
# 2023-01-01 04:00:00     4          6        1      1  2023          1
# ...                   ...        ...      ...    ...   ...        ...
# 2023-09-13 14:00:00    14          2        3      9  2023        256
# 2023-09-13 15:00:00    15          2        3      9  2023        256
# 2023-09-13 16:00:00    16          2        3      9  2023        256
# 2023-09-13 17:00:00    17          2        3      9  2023        256
# 2023-09-13 18:00:00    18          2        3      9  2023        256
#
#                      dayofmonth  weekofyear season  holiday
# date
# ...

# %%
X_test
# Out:
#                      hour  dayofweek  quarter  month  year  dayofyear  \
# date
# 2023-09-13 19:00:00    19          2        3      9  2023        256
# 2023-09-13 20:00:00    20          2        3      9  2023        256
# 2023-09-13 21:00:00    21          2        3      9  2023        256
# 2023-09-13 22:00:00    22          2        3      9  2023        256
# 2023-09-13 23:00:00    23          2        3      9  2023        256
# ...                   ...        ...      ...    ...   ...        ...
# 2023-12-31 19:00:00    19          6        4     12  2023        365
# 2023-12-31 20:00:00    20          6        4     12  2023        365
# 2023-12-31 21:00:00    21          6        4     12  2023        365
# 2023-12-31 22:00:00    22          6        4     12  2023        365
# 2023-12-31 23:00:00    23          6        4     12  2023        365
#
#                      dayofmonth  weekofyear season  holiday
# date
# ...

# %%
y_test
# Out:
# date
# 2023-09-13 19:00:00    106
# 2023-09-13 20:00:00     95
# 2023-09-13 21:00:00     86
# 2023-09-13 22:00:00     74
# 2023-09-13 23:00:00     54
#                       ...
# 2023-12-31 19:00:00     41
# 2023-12-31 20:00:00     33
# 2023-12-31 21:00:00     42
# 2023-12-31 22:00:00     33
# 2023-12-31 23:00:00     14
# Name: Crime Count, Length: 2621, dtype: int64

# %%
df_n
# Out:
#                      Crime Count                date  hour  dayofweek  \
# date
# 2023-01-01 00:00:00          170 2023-01-01 00:00:00     0          6
# 2023-01-01 01:00:00           88 2023-01-01 01:00:00     1          6
# 2023-01-01 02:00:00           85 2023-01-01 02:00:00     2          6
# 2023-01-01 03:00:00           79 2023-01-01 03:00:00     3          6
# 2023-01-01 04:00:00           69 2023-01-01 04:00:00     4          6
# ...                          ...                 ...   ...        ...
# 2023-12-31 19:00:00           41 2023-12-31 19:00:00    19          6
# 2023-12-31 20:00:00           33 2023-12-31 20:00:00    20          6
# 2023-12-31 21:00:00           42 2023-12-31 21:00:00    21          6
# 2023-12-31 22:00:00           33 2023-12-31 22:00:00    22          6
# 2023-12-31 23:00:00           14 2023-12-31 23:00:00    23          6
#
#                      quarter  month  year  dayofyear  dayofmonth  weekofyear  \
# date
# ...

# %%
plt.figure(figsize=(17, 7))
plt.plot(y_train, label='Training Set')
plt.plot(y_test, label='Test Set')
plt.legend()
plt.show()

# %%
# train = df_n.loc[df_n.index < '01-01-2018']
# test = df_n.loc[df_n.index >= '01-01-2018']
# train

# %%
# train = create_features(train)
# test = create_features(test)

# FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year']
# TARGET = 'Crime Count'

# X_train = train[FEATURES]
# y_train = train[TARGET]

# X_test = test[FEATURES]
# y_test = test[TARGET]
# train.info()

# %% [markdown]
# #XG Boost Regression

# %%
from xgboost import XGBRegressor


xgb = XGBRegressor( base_score=0.5, booster= 'gbtree',objective='reg:squarederror',
                       n_estimators=346,
                   early_stopping_rounds=10,
                     max_leaves=30,
                     learning_rate = 0.01, enable_categorical=True)

# Train the model
xgb.fit(X_train, y_train,
       eval_set=[(X_train, y_train), (X_test, y_test)],
         verbose=10)
# Out:
# [0]	validation_0-rmse:66.61376	validation_1-rmse:64.41910
# [10]	validation_0-rmse:60.42923	validation_1-rmse:58.15479
# [20]	validation_0-rmse:54.84748	validation_1-rmse:52.52645
# [30]	validation_0-rmse:49.81348	validation_1-rmse:47.47842
# [40]	validation_0-rmse:45.27901	validation_1-rmse:42.93431
# [50]	validation_0-rmse:41.19772	validation_1-rmse:38.85571
# [60]	validation_0-rmse:37.52521	validation_1-rmse:35.21303
# [70]	validation_0-rmse:34.22220	validation_1-rmse:31.94112
# [80]	validation_0-rmse:31.25743	validation_1-rmse:29.03006
# [90]	validation_0-rmse:28.59933	validation_1-rmse:26.43546
# [100]	validation_0-rmse:26.22138	validation_1-rmse:24.12990
# [110]	validation_0-rmse:24.09688	validation_1-rmse:22.09681
# [120]	validation_0-rmse:22.20079	validation_1-rmse:20.30962
# [130]	validation_0-rmse:20.51384	validation_1-rmse:18.75383
# [140]	validation_0-rmse:19.01617	validation_1-rmse:17.40831
# [150]	validation_0-rmse:17.68957	validation_1-rmse:16.25516
# ...

# %%
results = xgb.evals_result()
val_error_test = results['validation_1']['rmse']
val_error_train = results['validation_0']['rmse']

# %%
plt.plot(val_error_test)
plt.plot(val_error_train, color='orange')
plt.legend(['Testing rmse', 'Training rmse'])
plt.xlabel('Boosting rounds')
plt.ylabel('RMSE')
plt.show()

# %%
X_test
# Out:
#                      hour  dayofweek  quarter  month  year  dayofyear  \
# date
# 2023-09-13 19:00:00    19          2        3      9  2023        256
# 2023-09-13 20:00:00    20          2        3      9  2023        256
# 2023-09-13 21:00:00    21          2        3      9  2023        256
# 2023-09-13 22:00:00    22          2        3      9  2023        256
# 2023-09-13 23:00:00    23          2        3      9  2023        256
# ...                   ...        ...      ...    ...   ...        ...
# 2023-12-31 19:00:00    19          6        4     12  2023        365
# 2023-12-31 20:00:00    20          6        4     12  2023        365
# 2023-12-31 21:00:00    21          6        4     12  2023        365
# 2023-12-31 22:00:00    22          6        4     12  2023        365
# 2023-12-31 23:00:00    23          6        4     12  2023        365
#
#                      dayofmonth  weekofyear season  holiday
# date
# ...

# %%
imp = pd.DataFrame(data=xgb.feature_importances_,
             index=xgb.feature_names_in_,
             columns=['importance'])
imp.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
test = pd.DataFrame(y_test)
test['prediction'] = xgb.predict(X_test)
train = pd.DataFrame(y_train)
train['prediction'] = xgb.predict(X_train)

# unscaled = pd.DataFrame(scaler.inverse_transform(test),columns=test.columns)
# print(test)
# print(unscaled)
plt.figure(figsize=(10,5))
# df_n = df_n.merge(forest.predict(X_test), how='left', left_index=True, right_index=True)
plt.plot(df_year,zorder=1)
plt.scatter(test.index, test['prediction'], color='orange', zorder=2)

plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.xlabel('Time')
plt.show()

# %%
test_n = test.loc[(test.index >= start) & (test.index <= end)]

plt.figure(figsize=(17,7))
plt.plot(test_n['Crime Count'])
plt.plot(test_n.index, test_n['prediction'], color='orange')
plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
train_rmse = np.sqrt(train_mse)
train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
train_r2 = r2_score(train['Crime Count'], train['prediction'])

print("The R-squared of the model on the training set :", train_r2)
print(f"The mean squared error of the model on the training set : {train_mse:.3f}")
print(f"The root mean squared error of the model on the training set : {train_rmse:.3f}")
print(f"The mean absolute error of the model on the training set : {train_mae:.3f}\n")

test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
test_r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model is:", test_r2)
print(f"The mean squared error of the model on the testing set : {test_mse:.3f}")
print(f"The root mean squared error of the model on the testing set : {test_rmse:.3f}")
print(f"The mean absolute error of the model on the testing set : {test_mae:.3f}")
# Out:
# The R-squared of the model on the training set : 0.8514978033990616
# The mean squared error of the model on the training set : 96.365
# The root mean squared error of the model on the training set : 9.817
# The mean absolute error of the model on the training set : 7.589
#
# The R-squared of the model is: 0.7969638237076143
# The mean squared error of the model on the testing set : 133.544
# The root mean squared error of the model on the testing set : 11.556
# The mean absolute error of the model on the testing set : 9.072

# %%
tr_acc=xgb.score(X_train,y_train)*100
te_acc=xgb.score(X_test,y_test)*100
print(f'Training r2 score: {tr_acc:.2f} %')
print(f'Testing r2 score: {te_acc:.2f} %')
# Out:
# Training r2 score: 85.15 %
# Testing r2 score: 79.70 %

# %%
typ = '2D'
df_month = y_test.resample(typ).size().to_frame('Crime Count')
df_month=df_month[1:]
gen = df_month.drop(['Crime Count'], axis=1)
df_month = df_month.index

# %%
test = pd.DataFrame(y_test)
test['prediction'] = xgb.predict(X_test)

generalization = []
for x in df_month:
  test_new = test.loc[(test.index>='2023-09-13 19:00:00') & (test.index <= x)]
  test_r2 = r2_score(test_new['Crime Count'], test_new['prediction'])*100
  generalization.append(round(test_r2, 2))

# %%
gen['generalization'] = generalization

# %%
# plt.figure(figsize=(9,7))
plt.plot(gen.index, gen['generalization'])
plt.legend(['Generalization'])
plt.title('Generalization on increasing Test Data by 2 days')
plt.ylabel('R2_score(%)')
plt.xlabel('Time')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# Load the data

# Create a decision tree regressor
model = DecisionTreeRegressor(max_features=0.7,
                     max_depth=20, min_samples_leaf=30)
np.random.seed(0)
# Fit the model to the data
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=20, max_features=0.7, min_samples_leaf=30)

# %%
feature_names = X_train.columns
imp = pd.DataFrame(data=model.feature_importances_,
             index=feature_names,
             columns=['importance'])
imp.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
test = pd.DataFrame(y_test)
test['prediction'] = model.predict(X_test)
train = pd.DataFrame(y_train)
train['prediction'] = model.predict(X_train)

# unscaled = pd.DataFrame(scaler.inverse_transform(test),columns=test.columns)
# print(test)
# print(unscaled)
plt.figure(figsize=(17,7))
# df_n = df_n.merge(forest.predict(X_test), how='left', left_index=True, right_index=True)
plt.plot(df_year,zorder=1)
plt.scatter(test.index, test['prediction'], color='orange', zorder=2)

plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
test
# Out:
#                      Crime Count  prediction
# date
# 2023-09-13 19:00:00          106   97.339286
# 2023-09-13 20:00:00           95   89.081633
# 2023-09-13 21:00:00           86   82.806452
# 2023-09-13 22:00:00           74   73.603774
# 2023-09-13 23:00:00           54   61.520833
# ...                          ...         ...
# 2023-12-31 19:00:00           41   87.533333
# 2023-12-31 20:00:00           33   87.533333
# 2023-12-31 21:00:00           42   77.789474
# 2023-12-31 22:00:00           33   73.603774
# 2023-12-31 23:00:00           14   69.684211
#
# [2621 rows x 2 columns]

# %%
# start = '2007-07-20'
# end = '2007-07-30'
test_n = test.loc[(test.index >= start) & (test.index <= end)]

plt.figure(figsize=(17,7))
plt.plot(test_n['Crime Count'])
plt.plot(test_n.index, test_n['prediction'], color='orange')
plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
train_rmse = np.sqrt(train_mse)
train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
train_r2 = r2_score(train['Crime Count'], train['prediction'])

print("The R-squared of the model on the training set :", train_r2)
print(f"The root mean squared error of the model on the training set : {train_rmse:.3f}")
print(f"The mean absolute error of the model on the training set : {train_mae:.3f}\n")

test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
test_r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model on testing set is:", test_r2)
print(f"The root mean squared error of the model on the testing set : {test_rmse:.3f}")
print(f"The mean absolute error of the model on the testing set : {test_mae:.3f}")
# Out:
# The R-squared of the model on the training set : 0.8619751891488071
# The root mean squared error of the model on the training set : 9.464
# The mean absolute error of the model on the training set : 7.334
#
# The R-squared of the model on testing set is: 0.7594272964736208
# The root mean squared error of the model on the testing set : 12.579
# The mean absolute error of the model on the testing set : 9.819

# %%
tr_acc=train_r2*100
te_acc=test_r2*100
print(f'Training R2 Score: {tr_acc:.2f} %')
print(f'Testing R2 Score: {te_acc:.2f} %')
# Out:
# Training R2 Score: 86.20 %
# Testing R2 Score: 75.94 %

# %% [markdown]
# #Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor( max_features=0.7,
                n_estimators=1000,
                     max_depth=15, min_samples_leaf=30
                     )

forest.fit(X_train, y_train)
forest.score(X_test,y_test)
# Out:
# 0.7664356235628329

# %%
forest.score(X_train,y_train)
# Out:
# 0.8630621853708029

# %%
imp = pd.DataFrame(data=forest.feature_importances_,
             index=forest.feature_names_in_,
             columns=['importance'])

imp.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
# df_n = create_features(df_year)
test = pd.DataFrame(y_test)
test['prediction'] = forest.predict(X_test)
train = pd.DataFrame(y_train)
train['prediction'] = forest.predict(X_train)
# unscaled = pd.DataFrame(scaler.inverse_transform(test),columns=test.columns)
# print(test)
# print(unscaled)
plt.figure(figsize=(17,7))
# df_n = df_n.merge(forest.predict(X_test), how='left', left_index=True, right_index=True)
plt.plot(df_year,zorder=1)
plt.scatter(test.index, test['prediction'], color='orange', zorder=2)

plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
test_n = test.loc[(test.index >= start) & (test.index <= end)]

plt.figure(figsize=(17,7))
plt.plot(test_n['Crime Count'])
plt.scatter(test_n.index, test_n['prediction'], color='orange')
plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
train_rmse = np.sqrt(train_mse)
train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
train_r2 = r2_score(train['Crime Count'], train['prediction'])

print("The R-squared of the model on the train set :", train_r2)
print(f"The root mean squared error of the model on the train set : {train_rmse:.3f}")
print(f"The mean absolute error of the model on the train set : {train_mae:.3f}\n")

test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
test_r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model on the test set is:", test_r2)
print(f"The root mean squared error of the model on the test set : {test_rmse:.3f}")
print(f"The mean absolute error of the model on the test set : {test_mae:.3f}")
# Out:
# The R-squared of the model on the train set : 0.8630621853708029
# The root mean squared error of the model on the train set : 9.427
# The mean absolute error of the model on the train set : 7.232
#
# The R-squared of the model on the test set is: 0.7664356235628329
# The root mean squared error of the model on the test set : 12.394
# The mean absolute error of the model on the test set : 9.821

# %%
tr_acc=forest.score(X_train,y_train)*100
te_acc=forest.score(X_test,y_test)*100
print(f'R2 score on training: {tr_acc:.2f} %')
print(f'R2 score on testing: {te_acc:.2f} %')
# Out:
# R2 score on training: 86.31 %
# R2 score on testing: 76.64 %

# %% [markdown]
# #LGBM Regression

# %%
import lightgbm as lgb

# Create the dataset for LightGBM
# lgb_train = lgb.Dataset()


model = lgb.LGBMRegressor(force_col_wise=True, n_estimators=240, early_stopping_rounds=10,
                     max_depth=15,
                     learning_rate =0.01, num_leaves=30, verbose=-1)

# Train the model
model.fit(X_train, y_train, eval_metric='rmse', eval_set=[(X_train, y_train)])
# Out:
# LGBMRegressor(early_stopping_rounds=10, force_col_wise=True, learning_rate=0.01,
#               max_depth=15, n_estimators=240, num_leaves=30, verbose=-1)

# %%
imp = pd.DataFrame(data=model.feature_importances_,
             index=model.feature_name_,
             columns=['importance'])
imp.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
test = pd.DataFrame(y_test)
test['prediction'] = model.predict(X_test)
train = pd.DataFrame(y_train)
train['prediction'] = model.predict(X_train)

plt.figure(figsize=(10,5))

plt.plot(df_year,zorder=1)
plt.scatter(test.index, test['prediction'], color='orange', zorder=2)

plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.xlabel('Time')
plt.show()

# %%
test_n = test.loc[(test.index >= start) & (test.index <= end)]

plt.figure(figsize=(17,7))
plt.plot(test_n['Crime Count'])
plt.plot(test_n.index, test_n['prediction'], color='orange')
plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
train_rmse = np.sqrt(train_mse)
train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
train_r2 = r2_score(train['Crime Count'], train['prediction'])

print("The R-squared of the model on the training set :", train_r2)
print(f"The root mean squared error of the model on the training set : {train_rmse:.3f}")
print(f"The mean absolute error of the model on the training set : {train_mae:.3f}\n")

test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
test_r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model on testing set is:", test_r2)
print(f"The root mean squared error of the model on the testing set : {test_rmse:.3f}")
print(f"The mean absolute error of the model on the testing set : {test_mae:.3f}")
# Out:
# The R-squared of the model on the training set : 0.8606636379282818
# The root mean squared error of the model on the training set : 9.509
# The mean absolute error of the model on the training set : 7.457
#
# The R-squared of the model on testing set is: 0.7653078695029227
# The root mean squared error of the model on the testing set : 12.424
# The mean absolute error of the model on the testing set : 9.994

# %%
tr_acc=model.score(X_train,y_train)*100
te_acc=model.score(X_test,y_test)*100
print(f'Training accuracy: {tr_acc:.2f} %')
print(f'Testing accuracy: {te_acc:.2f} %')
# Out:
# Training accuracy: 86.07 %
# Testing accuracy: 76.53 %

# %% [markdown]
# #Linear Regression

# %%
from sklearn.linear_model import LinearRegression
# Import SVR class
from sklearn.preprocessing import StandardScaler



model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions

# x_scaled = sc_X.fit_transform(X_test)
# y_pred = sc_y.inverse_transform(model.predict(x_scaled).reshape(-1,1))
# y_test_pred = sc_y.inverse_transform(model.predict(sc_X.transform(X_test)).reshape(-1,1))
# print(f"The predicted number of crimes in {state} in {start} to {end} is {y_pred.flatten()}")

# X_train, y_train

y_test_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_test_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_test_pred)
r2 = r2_score(y_test, y_test_pred)

print("The R-squared of the model is:", r2)
print(f"The root mean squared error of the model on the testing set is {rmse:.0f}")
print(f"The mean absolute error of the model on the testing set is {mae:.0f}")
# Out:
# The R-squared of the model is: 0.34038520364361546
# The root mean squared error of the model on the testing set is 21
# The mean absolute error of the model on the testing set is 17

# %%
test = pd.DataFrame(y_test)
test['prediction'] = model.predict(X_test)
train = pd.DataFrame(y_train)
train['prediction'] = model.predict(X_train)

plt.figure(figsize=(9,4))
plt.plot(df_n['Crime Count'], color="blue", label="Actual")
plt.plot(X_test.index, y_test_pred, color="red"  )
# plt.plot(x, y_pred , color="red", label="Performance")
# # plt.plot(np.arange(start, end), y_pred_svr, color="red")
plt.xlabel("Year")
plt.ylabel("Total IPC Crimes")

plt.title(f"Crime Prediction in {state} using Linear Regression")
plt.legend()
plt.show()

# %%
train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
train_rmse = np.sqrt(train_mse)
train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
train_r2 = r2_score(train['Crime Count'], train['prediction'])

print("The R-squared of the model on the training set :", train_r2)
print(f"The root mean squared error of the model on the training set : {train_rmse:.3f}")
print(f"The mean absolute error of the model on the training set : {train_mae:.3f}\n")

test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
test_r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model on testing set is:", test_r2)
print(f"The root mean squared error of the model on the testing set : {test_rmse:.3f}")
print(f"The mean absolute error of the model on the testing set : {test_mae:.3f}")
# Out:
# The R-squared of the model on the training set : 0.40301823381649593
# The root mean squared error of the model on the training set : 19.682
# The mean absolute error of the model on the training set : 16.087
#
# The R-squared of the model on testing set is: 0.34038520364361546
# The root mean squared error of the model on the testing set : 20.829
# The mean absolute error of the model on the testing set : 16.947

# %%
tr_acc=model.score(X_train,y_train)*100
te_acc=model.score(X_test,y_test)*100
print(f'Training R2_score {tr_acc:.2f} %')
print(f'Testing R2_score: {te_acc:.2f} %')
# Out:
# Training R2_score 40.30 %
# Testing R2_score: 34.04 %

# %%
test_n = test.loc[(test.index >= start) & (test.index <= end)]

plt.figure(figsize=(17,7))
plt.plot(test_n['Crime Count'])
plt.plot(test_n.index, test_n['prediction'], color='orange')
plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.show()

# %%
# from sklearn.svm import SVR # Import SVR class
# from sklearn.preprocessing import StandardScaler
# from sklearn.decomposition import PCA

# # Create and fit an SVR model with RBF kernel
# model_svr = SVR(kernel="rbf")
# model_svr



# # Fit the SVR object on the transformed training features and labels
# model_svr.fit(X_train, y_train)

# y_pred = model_svr.predict(X_test)

# mse = mean_squared_error(y_test, y_pred)
# r2 = r2_score(y_test, y_pred)

# # Print the results
# print('Mean squared error:', mse)
# print('R-squared:', r2)

# %%
# model_svr.fit(X_train, y_train)
# y_test_pred = model_svr.predict(X_test)

# mse = mean_squared_error(y_test, y_test_pred)
# rmse = np.sqrt(mse)
# mae = mean_absolute_error(y_test, y_test_pred)
# r2 = r2_score(y_test, y_test_pred)


# print("The R-squared of the model is:", r2)
# print(f"The root mean squared error of the model on the testing set is {rmse:.0f}")
# print(f"The mean absolute error of the model on the testing set is {mae:.0f}")

# score = model_svr.score(X_test, y_test)
# score

# %%
# test = pd.DataFrame(y_test)
# test['prediction'] = model_svr.predict(X_test)
# train = pd.DataFrame(y_train)
# train['prediction'] = model_svr.predict(X_train)

# plt.figure(figsize=(9,4))
# plt.plot(df_n['Crime Count'], color="blue", label="Actual")
# plt.plot(X_test.index, y_test_pred, color="red"  )
# # plt.plot(x, y_pred , color="red", label="Performance")
# # # plt.plot(np.arange(start, end), y_pred_svr, color="red")
# plt.xlabel("Year")
# plt.ylabel("Total IPC Crimes")

# plt.title(f"Crime Prediction in {state} using Linear Regression")
# plt.legend()
# plt.show()

# %%
# train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
# train_rmse = np.sqrt(train_mse)
# train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
# train_r2 = r2_score(train['Crime Count'], train['prediction'])

# print("The R-squared of the model on the training set :", train_r2)
# print(f"The root mean squared error of the model on the training set : {train_rmse:.3f}")
# print(f"The mean absolute error of the model on the training set : {train_mae:.3f}\n")

# test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
# test_rmse = np.sqrt(test_mse)
# test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
# test_r2 = r2_score(test['Crime Count'], test['prediction'])

# print("The R-squared of the model on testing set is:", test_r2)
# print(f"The root mean squared error of the model on the testing set : {test_rmse:.3f}")
# print(f"The mean absolute error of the model on the testing set : {test_mae:.3f}")

# %%
# test_n = test.loc[(test.index >= start) & (test.index <= end)]

# plt.figure(figsize=(17,7))
# plt.plot(test_n['Crime Count'])
# plt.scatter(test_n.index, test_n['prediction'], color='orange')
# plt.legend(['Actual Data', 'Predictions'])
# plt.title('Prediction on Test Data')
# plt.ylabel('Number of Crimes')
# plt.show()

# %% [markdown]
# #Polynomial Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
# Create and fit a polynomial regression model of degree 3
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X_train)
# y_scaled = scaler.fit_transform(y_train.values.reshape(-1,1))
# X_scaled = pd.DataFrame(X_scaled, columns = X_train.columns)
model_poly = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())

# poly = PolynomialFeatures(degree=2)
# X_poly = poly.fit_transform(X_train)

# model_poly = LinearRegression()
model_poly.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
test = pd.DataFrame(y_test)
test['prediction'] = model_poly.predict(X_test)
train = pd.DataFrame(y_train)
train['prediction'] = model_poly.predict(X_train)


mse = mean_squared_error(test['Crime Count'], test['prediction'])
rmse = np.sqrt(mse)
mae = mean_absolute_error(test['Crime Count'], test['prediction'])
r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model is:", r2)
print(f"The root mean squared error of the model on the testing set is {rmse:.0f}")
print(f"The mean absolute error of the model on the testing set is {mae:.0f}")
# Out:
# The R-squared of the model is: -31267950.795343347
# The root mean squared error of the model on the testing set is 143408
# The mean absolute error of the model on the testing set is 107985

# %%
plt.figure(figsize=(10,5))

plt.scatter(df_year.index, df_year['Crime Count'],zorder=1)
plt.scatter(test.index, test['prediction'], color='orange', zorder=2)

plt.legend(['Actual Data', 'Predictions'])
plt.title('Prediction on Test Data')
plt.ylabel('Number of Crimes')
plt.xlabel('Time')
plt.show()

# %%
plt.figure(figsize=(9,4))
plt.plot(test['Crime Count'].tail(500), color="blue", label="Actual")
plt.plot(test['prediction'].tail(500), color="orange")
plt.xticks(rotation=45)
plt.show()

# %%
train_mse = mean_squared_error(train['Crime Count'], train['prediction'])
train_rmse = np.sqrt(train_mse)
train_mae =  mean_absolute_error(train['Crime Count'], train['prediction'])
train_r2 = r2_score(train['Crime Count'], train['prediction'])

print("The R-squared of the model on the training set :", train_r2)
print(f"The root mean squared error of the model on the training set : {train_rmse:.3f}")
print(f"The mean absolute error of the model on the training set : {train_mae:.3f}\n")

test_mse = mean_squared_error(test['Crime Count'], test['prediction'])
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(test['Crime Count'], test['prediction'])
test_r2 = r2_score(test['Crime Count'], test['prediction'])

print("The R-squared of the model on testing set is:", test_r2)
print(f"The root mean squared error of the model on the testing set : {test_rmse:.3f}")
print(f"The mean absolute error of the model on the testing set : {test_mae:.3f}")
# Out:
# The R-squared of the model on the training set : 0.45645158909747163
# The root mean squared error of the model on the training set : 18.781
# The mean absolute error of the model on the training set : 15.099
#
# The R-squared of the model on testing set is: -31267950.795343347
# The root mean squared error of the model on the testing set : 143408.496
# The mean absolute error of the model on the testing set : 107985.367

# %%
tr_acc=model_poly.score(X_train,y_train)*100
te_acc=model_poly.score(X_test,y_test)*100
print(f'Training accuracy: {tr_acc:.2f} %')
print(f'Testing accuracy: {te_acc:.2f} %')
# Out:
# Training accuracy: 45.65 %
# Testing accuracy: -3126795079.53 %
